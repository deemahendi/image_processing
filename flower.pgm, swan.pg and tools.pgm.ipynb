# %% [markdown]
# 1. Compute and plot (show the image and its histogram) the histogram of flower.pgm, swan.pgm and tools.pgm. Comment on what information can be discerned about the images from an examination of the histogram.
#
# 2. Write a routine which implements the method of Otsu to compute the thresholds for flower.pgm, swan.pgm and tools.pgm. Show the resulting binary images.
#
#  Discuss and explain your results on the basis of the histogram and thresholding experiments
# ---------------------------------------------------------------------------------------------------------------------
#                                                Flower.pgm
#
#  Histogram : From the analysis of the histogram , as shown in 'flower' figure below, its clear that there are more dark pixels in the image than the light ones bacause the majority of the image pixels have the grayscale level of less than 150.
#
#                                                swan.pgm
#
# Histogram : From the analysis of the histogram , as shown in  'swan' figure below,swan.pgm can be classifies as a high contrast image,the maximum of the histogram is located in 250 which indicates high presence of white pixels on the image
#
#
#                                               tools.pgm
#
# Histogram : From the analysis of the histogram , as shown in  'tools' figure below tools.pgm can be classifies as a low  contrast image because most of pixels have the gray levels between 160 and 190 which indicates there are  light pixels more than dark ones
#
#
#
#  image segmentation using histogram thresholding works for separating the objects from the background when there are distinct local minima and maxima in the histograms. if we have  bi-modal histogram distribution  and there is one maximum for objects and one for background.  the two maxima are located relatively far away from each other and therefore the optimal threshold can be located somewhere in between the two peaks.  when the noise levels are high the method produces high level of pixel misclassification.

# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt 
img1 = cv2.imread('images/flower.pgm',0)
hist1 =cv2.calcHist([img1],[0],None,[256],[0,256])
plt.plot(hist1)
plt.show()

img = cv2.imread('images/flower.pgm')
grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#retval, threshold = cv2.threshold(grayscaled, 200,700, cv2.THRESH_BINARY)
retval, threshold = cv2.threshold(grayscaled,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
adaptive = cv2.adaptiveThreshold(grayscaled,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,815,1)
titles=['Orginal Flower','gray','OTSU','ADAPTIVE']
images=[img1,img,threshold,adaptive]
fig = plt.figure(figsize=(10,10))

for i in range(4):
    plt.subplot(2,4,i+1),plt.imshow(images[i], cmap = 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt 
img1 = cv2.imread('images/swan.pgm',0)
hist1 =cv2.calcHist([img1],[0],None,[256],[0,256])
plt.plot(hist1)
plt.show()

img = cv2.imread('images/swan.pgm')
grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
adaptive = cv2.adaptiveThreshold(grayscaled,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,815,1)
titles=['Orginal Flower','gray','OTSU','ADAPTIVE']
images=[img1,img,threshold,adaptive]
fig = plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(2,4,i+1),plt.imshow(images[i],cmap = 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt 
img1 = cv2.imread('images/tools.pgm',0)
hist1 =cv2.calcHist([img1],[0],None,[256],[0,256])
plt.plot(hist1)
plt.show()

img = cv2.imread('images/tools.pgm')
grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
adaptive = cv2.adaptiveThreshold(grayscaled,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,815,1)
titles=['Orginal Flower','gray','OTSU','ADAPTIVE']
images=[img1,img,threshold,adaptive]
fig = plt.figure(figsize=(10,10))

for i in range(4):
    plt.subplot(2,4,i+1),plt.imshow(images[i],cmap = 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()
